# %%
from pathlib import Path

import pandas as pd

import matplotlib.pyplot as plt

# %%
DATA_DIR_NAME = "data"
TAXI_FILENAME = "yellow_tripdata_2025-03.parquet"

# %%
try: 
    base_dir = Path(__file__).parent
except NameError:
    base_dir=Path.cwd()

taxi_file_path = base_dir.parent / DATA_DIR_NAME / TAXI_FILENAME
taxi_file_path
# Out:
# PosixPath('/Users/ecamp/code_sandbox/nyc_taxi/data/yellow_tripdata_2025-03.parquet')

# %%
taxi_df = pd.read_parquet(taxi_file_path)
